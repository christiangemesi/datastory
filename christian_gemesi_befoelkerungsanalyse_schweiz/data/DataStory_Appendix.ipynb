# %%
import folium

from helperFunctions import *

# %%
plotBubbleMap('2000')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# Wir sehen die erwähnte BubbleMap.

# %% [markdown]
# Im File "Datastory.ipynb" haben wir besonders Wert auf den Kanton Zürich gelegt. Hier werden wir nun die anderen Kantone Basel-Stadt, Genf, Bern und Appenzell Innerhoden abbilden, damit wir einen besseren vergleich haben.

# %% [markdown]
# #### Genf

# %%
wachstumAusgewähltesKantons('GE',True)
# Out:
# Median:  171183.0
# Mittelwert:  198839.0
# 25% Quartil: 104059.75
# 75% Quartil: 277325.25

# %% [markdown]
# Hier ist ein starkes Wachstum ersichtlich wie bei Zürich auch.

# %%
BarYearsWithStaedte('2000','GE' ,True)
# Out:
# Median:  2171.0
# Mittelwert:  9192.733333333334
# 25% Quartil: 1107.0
# 75% Quartil: 8114.0

# %% [markdown]
# Ebenso wie beim Kanton Zürich sehen wir dass die Stadt Genf selbst am beliebtesten ist.

# %% [markdown]
# ### Basel-Stadt

# %%
wachstumAusgewähltesKantons('BS',True)
# Out:
# Median:  147869.0
# Mittelwert:  138603.5625
# 25% Quartil: 71363.5
# 75% Quartil: 197226.25

# %% [markdown]
# Wir sehen dass es einen Trendwechsel gab von 1970 auf 1980. Daher haben wir nun ein fallendes Befölkerungswachstum beim Kanton Basel-Stadt.

# %%
BarYearsWithStaedte('2000','BS' ,True)
# Out:
# Median:  20370.0
# Mittelwert:  62693.0
# 25% Quartil: 10760.5
# 75% Quartil: 93464.0

# %% [markdown]
# Die Visualisierung ist relativ mager mit nur 3 Gemeinden, daher ist dieser Plot nicht aussagekräftig. Jedoch ebenso ersichtlich dass die Stadt Basel selbst sehr beliebt ist.

# %% [markdown]
# ### Appenzell Innerhoden

# %%
wachstumAusgewähltesKantons('AI',True)
# Out:
# Median:  13253.5
# Mittelwert:  13245.3125
# 25% Quartil: 12866.5
# 75% Quartil: 13899.5

# %% [markdown]
# Wir sehen dass AI sich setwärts verhält was das Befölkerungswachstum betrifft.

# %%
BarYearsWithStaedte('2000','AI' ,True)
# Out:
# Median:  1865.5
# Mittelwert:  2436.3333333333335
# 25% Quartil: 1483.25
# 75% Quartil: 2670.0

# %% [markdown]
# Selbst im Befölkerungsarmsten Kanton AI ist der Hauptort Appenzell am beliebtesten.

# %% [markdown]
# Aus unseren Untersuchungen sehen wir dass die Befölkerung der Schweiz am liebsten im Hauptort des jeweiligen Kantons wohnen.
