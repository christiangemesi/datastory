# %%
from helperFunctions import *

# %% [markdown]
# ### Abstract:
#
# Ich habe das Befölkerungswachstum der Schweiz analysiert. Dabei habe ich herausgefunden dass die meisten Personen am liebsten in Grossstdädten leben.

# %% [markdown]
# ### Introduction:
#
# Das Budesamt für Statistik hat eine Statistik veröffentlicht welches das Befölkerungswachstum der Schweiz von 1850 - 2000 zeigt. Diese Statistik ist jedoch nur in Zahlen abgebildet und nicht visualisiert. Daher war meine Idee diese Visuell anschaulich zu zeigen.
#
# Folgende Fragen werde ich untersuchen:
# - Welchen Stadt,Kanton am meisten personen zugezogen bzw am wenigsten
# - Sehen wir trends?
# - Wie sieht es bei den Grossstädten aus? Genf, Zürich, Bern, Basel
# - Wo leben die meisten Personen? Kanton und Stadt
# - Schlussendlich sollen die Resultate auf einer Karte visualisiert werden.
#
# Diese Fragen werden in den folgenden Plots beantwortet. Hat die Funktion ein Tag "Interaktiv", kann man ebenso eigene Kantonen/Jahre wählen, welche man betrachten möchte.

# %% [markdown]
# ### Results:

# %%
years = ["1860","1870", "1880","1890","1900","1910","1920","1930","1940","1950","1960","1970","1980","1990","2000"]
kantons = ["AG","AI","AR","BE","BL","BS","FR","GE","GL","GR","JU","LU","NE","NW","OW","SG","SH","SO","SZ","TG","TI","UR","VD","VS","ZG","ZH"]

dfYears = dfHeatMapCantons()

pd.DataFrame(np.random.randint(low=10000, high=200000, size=(15, 26)), index=years, columns=kantons)
dfYears.sort_values(by = '2000').style.background_gradient(cmap='YlOrRd')
# Out:
# <style type="text/css">
# #T_dac71_row0_col1, #T_dac71_row0_col2, #T_dac71_row0_col3, #T_dac71_row0_col4, #T_dac71_row0_col5, #T_dac71_row0_col6, #T_dac71_row0_col7, #T_dac71_row0_col8, #T_dac71_row0_col9, #T_dac71_row0_col10, #T_dac71_row0_col11, #T_dac71_row0_col12, #T_dac71_row0_col13, #T_dac71_row0_col14, #T_dac71_row0_col15, #T_dac71_row0_col16, #T_dac71_row3_col1, #T_dac71_row3_col2, #T_dac71_row3_col3, #T_dac71_row3_col4, #T_dac71_row3_col5, #T_dac71_row3_col6, #T_dac71_row3_col7, #T_dac71_row3_col8, #T_dac71_row3_col9 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_dac71_row1_col1, #T_dac71_row1_col2, #T_dac71_row1_col3, #T_dac71_row1_col4, #T_dac71_row1_col5, #T_dac71_row1_col6, #T_dac71_row1_col7, #T_dac71_row1_col8, #T_dac71_row3_col10, #T_dac71_row3_col11 {
#   background-color: #fffecb;
#   color: #000000;
# }
# ...

# %% [markdown]
# Wir reduzieren unsere Analyse hier auf folgende Kantone:
#
# - Zürich
# In Zürich sind mit abstand die meisten Personen zugezogen.
# von ~250'000 -> ~1'200'000 Faktor ~5
#
# - Bern
# Der zweit Befölkerungsreichster Kanton
# von ~400'000 -> ~950'000 Faktor ~2
#
# - Genf
# Der sechst Befölkerungsreichster Kanton
# von ~ 65'000 -> ~415'000 Faktor ~6
#
# - Basel-Stadt
# von ~ 30'000 -> ~190'000 Faktor ~6
#
# - Appenzell Innerrhoden
# von ~ 14'660 -> ~14'618 Faktor ~1
#
# Grundsätzlich sehen wir bei allen Kantonen ein Wachstum (mit wenigen Ausnahmen). Dabei ist ersichtlich dass besonders die Grossstädte ein besonders hohes Befölkerungswachstum hatten.

# %% [markdown]
# Der BubblePlot in DataStory_Appendix zeigt dieses Wachstum nochmals deutlich in Relation.

# %%
"Interaktive"
wachstumAusgewähltesKantons('ZH',True)
# Out:
# Median:  578154.0
# Mittelwert:  662932.125
# 25% Quartil: 331905.75
# 75% Quartil: 991175.0

# %% [markdown]
# Hier ist das Wachstum von Zürich über die Jahre ersichtlich. Vergleichen wir dieses mit den anderen (oben erwähnten) Kantonen sehen wir dass sich bis auf AI alle relativ ähnlich verhalten haben was das Wachstum betrifft.

# %%
"Interaktive"
BarYearsWithStaedte('2000','ZH' ,True)
# Out:
# Median:  3083.0
# Mittelwert:  7297.695906432748
# 25% Quartil: 1275.5
# 75% Quartil: 6030.0

# %% [markdown]
# Hier sehen wir dass besonders die Stadt Zürich selbst sehr beliebt ist. Verglichen mit den oberen Kantonen sieht das bei allen (ausser AI) relativ ähnlich aus.

# %% [markdown]
# ### Conclusion:
#
# Es ist interessant zu sehen, dass besonders bei Genf, Bern und Zürich der grösste Teil der Befölkerung in einer Stadt lebt.
# Ausserdem ist es interessant zu sehen, dass sich der Unterschied in den Einzelnen Kantonen erneut unterscheided. Der Faktor zwischen dem beliebtesten und der unbeliebtesten Stadt ist enorm.
#
# Die Schweiz ist generell sehr Beliebt, was man am Wachstum zwischen 1850 und 2000 sehen kann.
#
# Was man noch weiteres tun könnt:
# - Man hätte das Geojson file für den Bubbleplot erweitern können um alle Städte einzeln zu zeigen.
# - Man hätte Einen Slider beim Bubbleplot hinzufügen können, somit hätte es die Handhabung erleichtert.
